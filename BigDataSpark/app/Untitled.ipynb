# %%
# !java -version
# Out:
# openjdk version "11.0.22" 2024-01-16
# OpenJDK Runtime Environment Temurin-11.0.22+7 (build 11.0.22+7)
# OpenJDK 64-Bit Server VM Temurin-11.0.22+7 (build 11.0.22+7, mixed mode, sharing)

# %%
# test_spark.py
from pyspark.sql import SparkSession

# Простая сессия без внешнего кластера
spark = SparkSession.builder \
    .appName("LocalTest") \
    .master("local[*]") \
    .config("spark.jars", "/opt/spark/jars/postgresql-42.6.0.jar") \
    .config("spark.driver.extraClassPath", "/opt/spark/jars/*") \
    .getOrCreate()

print("Spark version:", spark.version)
print("Spark session created successfully!")

# Простой тест
df = spark.range(5)
df.show()

spark.stop()
# Out:
# 25/11/18 13:41:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Spark version: 3.5.7
# Spark session created successfully!
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+

# %%
# Диагностика окружения
import sys
import subprocess
import os

print("Python version:", sys.version)
print("Java home:", os.environ.get('JAVA_HOME', 'Not set'))

# Проверяем Java
try:
    result = subprocess.run(['java', '-version'], capture_output=True, text=True)
    print("Java version check:")
    print(result.stderr)
except Exception as e:
    print("Java not found:", e)

# Проверяем переменные окружения
print("\nEnvironment variables:")
for key in ['SPARK_HOME', 'PYSPARK_PYTHON', 'PYSPARK_DRIVER_PYTHON', 'JAVA_HOME']:
    print(f"{key}: {os.environ.get(key, 'Not set')}")
# Out:
# Python version: 3.10.12 (main, Aug 15 2025, 14:32:43) [GCC 11.4.0]
# Java home: /opt/java/openjdk
# Java version check:
# openjdk version "17.0.16" 2025-07-15
# OpenJDK Runtime Environment Temurin-17.0.16+8 (build 17.0.16+8)
# OpenJDK 64-Bit Server VM Temurin-17.0.16+8 (build 17.0.16+8, mixed mode, sharing)
#
#
# Environment variables:
# SPARK_HOME: /opt/spark
# PYSPARK_PYTHON: Not set
# PYSPARK_DRIVER_PYTHON: Not set
# JAVA_HOME: /opt/java/openjdk
